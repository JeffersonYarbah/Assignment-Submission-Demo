# %%
#GIVE A LIST AND SORT IT IN DECENDING ORDER
#IN THIS CONTEST I AM USING TWO WAYS

'''
FIRST WAY
'''

li=['Antilope','Bat','Cat','Dog','Elephant']
print("THIS IS A LIST OF ANIMALS")
li.sort(reverse=True)
print(li)
# Out:
# THIS IS A LIST OF ANIMALS
# ['Elephant', 'Dog', 'Cat', 'Bat', 'Antilope']

# %%
'''
SECOND WAY
'''
li=[140,275,48,676,550]
print("THIS IS A LIST OF FIGURES")
li.sort()
li.reverse()
print(li)
# Out:
# THIS IS A LIST OF FIGURES
# [676, 550, 275, 140, 48]
