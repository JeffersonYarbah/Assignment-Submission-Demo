# %%
#OTP GENERATION

import random as r
import string
length=8
otp=''

characters=string.ascii_letters + string.digits
print(characters)
for i in rannge(length):
  opt=otp+(r.choice(characters))
  print(opt)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-27f595459ad2> in <module>()
#       8 characters=string.ascii_letters + string.digits
#       9 print(characters)
# ---> 10 for i in rannge(length):
#      11   opt=otp+(r.choice(characters))
#      12   print(opt)
#
# NameError: name 'rannge' is not defined

# %%
#REMOVE ALL THE OCCURENCES OS AN ELEMENT FROM A LIST
#USING THE LOOPING METHOD

li=['John', 'Peter', 'John', 'Alex', 'John', 'Henry', 'John', 'Joe', 'Dennis']

while li.count('John')>0:
 li.remove('John')
print(li)
# Out:
# ['Peter', 'Alex', 'Henry', 'Joe', 'Dennis']
